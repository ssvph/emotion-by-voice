# %% [markdown]
# # Задача определния эмоции человека по аудио (голосу)
# Метрика машинного обучения: количество верно классифицированных эмоций.
#
# Применимость для бизнеса:
#  - внедрить обученную модель в рекомендательную систему для повышения точности рекомендаций развлекательного контента (предположительно посредством ссылок на контент), а также увеличения количества запросов к сервису, возвращаемости пользователей
#  - отслеживание перехода пользователям по ссылке и времени проведенном на сайте.
#
# ## Обучающие данные
# В работе используется подготовленный сет данных - Dusha. Состоящий из ...

# %%
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
import csv
import json
import pandas as pd

# %% [markdown]
# Декомпозиция звуковых дорожек с эмоциями "Злость" и "Нейтраль".

# %%
#emotion=anger
features_path = "./Dusha/features/features/11704a9519489f2dcfe948e8130881b4.npy"
one_of_features_npy = np.load(features_path)

plt.imshow(one_of_features_npy[0])
plt.show()

# %%
#emotion=neutral
features_path2 = "./Dusha/features/features/b40eba2d6720c80fe29af3327f84bb51.npy"
one_of_features_npy2 = np.load(features_path2)

plt.imshow(one_of_features_npy2[0])
plt.show()

# %% [markdown]
# ## Обучение модели

# %%
# create pandas DataFrame
raw_crowd_test = pd.read_json('Dusha/crowd/crowd_test/raw_crowd_test.jsonl',lines=True)[['hash_id','audio_path']]
raw_crowd_train = pd.read_json('Dusha/crowd/crowd_train/raw_crowd_train.jsonl',lines=True)[['hash_id','audio_path']]
raw_crowd_test.head()
# Out:
#                             hash_id                                 audio_path
# 0  9e9961c53ca6eeb440b217e539fbf46c  wavs/9e9961c53ca6eeb440b217e539fbf46c.wav
# 1  0166f65a30354db8282682b1a280e64c  wavs/0166f65a30354db8282682b1a280e64c.wav
# 2  d49a6b560155831725a7bdc7d0a96099  wavs/d49a6b560155831725a7bdc7d0a96099.wav
# 3  c6852b0925797612d7b6724da8cbe7b4  wavs/c6852b0925797612d7b6724da8cbe7b4.wav
# 4  0166f65a30354db8282682b1a280e64c  wavs/0166f65a30354db8282682b1a280e64c.wav

# %%
crowd_test = pd.read_json('Dusha/paper_setups/paper_setups/test/crowd_test.jsonl', lines=True)[['id','tensor','label']]
crowd_test['id'][0]
# Out:
# '9e9961c53ca6eeb440b217e539fbf46c'

# %%
#DELETE
features_npy2 = np.load('./Dusha/features/features/{0}.npy'.format(crowd_test['id'][0]))

plt.imshow(features_npy2[0])
plt.show()

# %%
id_label = []
k=0
for i in crowd_test['id']:
    id_label.append(np.load('./Dusha/features/features/{0}.npy'.format(i)))
    k+=1
    print('Iteration {0}'.format(k))
id_label
# Out:
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29
# Iteration 30
# Iteration 31
# Iteration 32
# Iteration 33
# Iteration 34
# Iteration 35
# Iteration 36
# Iteration 37
# Iteration 38
# Iteration 39
# Iteration 40
# Iteration 41
# Iteration 42
# Iteration 43
# Iteration 44
# Iteration 45
# Iteration 46
# Iteration 47
# Iteration 48
# Iteration 49
# Iteration 50
# Iteration 51
# Iteration 52
# Iteration 53
# Iteration 54
# Iteration 55
# Iteration 56
# Iteration 57
# Iteration 58
# Iteration 59
# Iteration 60
# Iteration 61
# Iteration 62
# Iteration 63
# Iteration 64
# Iteration 65
# Iteration 66
# Iteration 67
# ...

# %%
len(crowd_test)
# Out:
# 13863

# %%
raw_crowd_train_path = "./Dusha/crowd/crowd_train/raw_crowd_train.tsv"

with open (raw_crowd_train_path, encoding='utf-8') as RCTrainP:
    for line in csv.reader(RCTrainP, delimiter="\t"):
        print(line)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
